# %%
import os

def print_directory_tree(path, indent=""):
    with os.scandir(path) as entries:
        for entry in entries:
            if entry.is_dir():
                print(f"{indent}+-- {entry.name}")
                print_directory_tree(entry.path, indent + "    ")
            else:
                print(f"{indent}|-- {entry.name}")

if __name__ == "__main__":
    current_dir = os.getcwd()
    print(f"Directory Tree for: {current_dir}")
    print_directory_tree(current_dir)
# Out:
# Directory Tree for: /home/vincent/MySSD/JupyterProjects/AAA_projects/UnlimitedResearchCooperative/Synthetic_Intelligence_Labs/Human-Brain-Rat/Software/FPGA
# |-- ax301.jic
# +-- .ipynb_checkpoints
#     |-- file_tree-checkpoint.ipynb
# +-- AX301_BOOT_PRJ
#     |-- tb.sv.bak
#     |-- my_design_tb.sv
#     +-- i2c_master
#         |-- i2c_master_bit_ctrl.sv
#         |-- i2c_master_bit_ctrl.sv.bak
#         +-- .ipynb_checkpoints
#             |-- i2c_master_byte_ctrl-checkpoint.sv
#         |-- lut_ov5640_rgb565_1024_768.sv
#         |-- i2c_master_byte_ctrl.sv
#         |-- i2c_master_top.sv
#         |-- timescale.sv
#         |-- i2c_master_byte_ctrl.sv.bak
#         |-- i2c_com.sv
#         |-- i2c_config.sv
#         |-- i2c_master_defines.sv
#     |-- i2s_tx.sv.bak
#     |-- top.sv.bak
#     +-- simulation
#         +-- modelsim
#             |-- top.sft
#             |-- top.svo
#             |-- top_modelsim.xrf
#     |-- top.qpf
#     |-- total.tcl
#     |-- top.qsf
#     +-- constraints
#     |-- SDC1.sdc
#     +-- .ipynb_checkpoints
#         |-- ax_debounce-checkpoint.sv
#         |-- top-checkpoint.qsf
#         |-- i2s_tx-checkpoint.sv
#         |-- top-checkpoint.qpf
#         |-- top.restore-checkpoint.rpt
#         |-- ax301_ax4010-checkpoint.tcl
#         |-- notes-checkpoint
#         |-- SDC1-checkpoint.sdc
#         |-- top.sv-checkpoint.bak
#         |-- SDC1.sdc-checkpoint.bak
#         |-- i2s_tx.sv-checkpoint.bak
#         |-- top-checkpoint.sv
#         |-- top.archive-checkpoint.rpt
#         |-- tb.sv-checkpoint.bak
#         |-- top_assignment_defaults-checkpoint.qdf
#         |-- my_design_tb-checkpoint.sv
#         |-- total-checkpoint.tcl
#         |-- tb-checkpoint.sv
#         |-- assignment_defaults-checkpoint.qdf
#     |-- SDC1.sdc.bak
#     |-- top.restore.rpt
#     +-- output
#     |-- top_assignment_defaults.qdf
#     +-- db
#         |-- top.cmp_merge.kpt
#         |-- top.lpc.html
#         |-- top.eda.qmsg
#         |-- top.lpc.txt
#         |-- top.map.qmsg
#         |-- top.(3).cnf.cdb
#         |-- top.sta.qmsg
#         |-- top.tiscmp.fast_1200mv_0c.ddb
#         |-- top.fit.qmsg
#         |-- top.map.bpm
#         |-- top.cbx.xml
#         |-- top.cycloneive_io_sim_cache.45um_ss_1200mv_0c_slow.hsd
#         |-- top.map_bb.logdb
#         |-- top.asm.qmsg
#         |-- top.sta_cmp.8_slow_1200mv_85c.tdb
#         |-- top.smart_action.txt
#         |-- top.asm.rdb
#         |-- top.(0).cnf.cdb
#         |-- top.tiscmp.slow_1200mv_0c.ddb
#         |-- top.routing.rdb
#         |-- top.lpc.rdb
#         |-- top.map.rdb
#         |-- top.(0).cnf.hdb
#         |-- top.map_bb.cdb
#         |-- top.cmp.idb
#         |-- top.hif
#         |-- top.asm_labs.ddb
#         |-- top.(2).cnf.cdb
#         |-- top.sld_design_entry_dsc.sci
#         |-- top.rtlv_sg.cdb
#         |-- top.(3).cnf.hdb
#         |-- top.cmp.rdb
#         |-- top.smp_dump.txt
#         |-- top.cycloneive_io_sim_cache.45um_ss_1200mv_85c_slow.hsd
#         |-- .cmp.kpt
#         |-- top.rtlv.hdb
#         |-- top_partition_pins.json
#         |-- top.cmp.hdb
#         |-- top.(1).cnf.hdb
#         |-- top.map.kpt
#         |-- top.tis_db_list.ddb
#         |-- top.rtlv_sg_swap.cdb
#         |-- top.cycloneive_io_sim_cache.45um_ff_1200mv_0c_fast.hsd
#         |-- top.map.hdb
#         |-- top.pre_map.hdb
#         |-- top.map.ammdb
#         |-- top.cmp.bpm
#         |-- top.vpr.ammdb
#         |-- top.tiscmp.fastest_slow_1200mv_0c.ddb
#         |-- top.(2).cnf.hdb
#         |-- prev_cmp_top.qmsg
#         |-- top.map_bb.hdb
#         |-- top.map.cdb
#         |-- top.(5).cnf.hdb
#         |-- top.tiscmp.slow_1200mv_85c.ddb
#         |-- top.(1).cnf.cdb
#         |-- top.hier_info
#         |-- top.(5).cnf.cdb
#         |-- top.cmp.logdb
#         |-- top.db_info
#         |-- top.root_partition.map.reg_db.cdb
#         |-- top.tiscmp.fastest_slow_1200mv_85c.ddb
#         |-- top.cmp.cdb
#         |-- top.map.logdb
#         |-- top.sta.rdb
#     |-- ax301_ax4010.tcl
#     +-- output_files
#         |-- top.jdi
#         |-- top.eda.rpt
#         |-- top.fit.rpt
#         |-- top.done
#         |-- top.map.rpt
#         |-- top.map.smsg
#         |-- top.asm.rpt
#         |-- top.fit.summary
#         |-- top.flow.rpt
#         |-- top.sld
#         |-- top.sta.summary
#         |-- top.map.summary
#         |-- top.fit.smsg
#         |-- top.sta.rpt
#         |-- top.sof
#         |-- top.pin
#     |-- assignment_defaults.qdf
#     |-- notes
#     |-- ax_debounce.sv
#     |-- top.qws
#     |-- top.sv
#     +-- scripts
#     |-- top.archive.rpt
#     |-- i2s_tx.sv
#     +-- source
#         |-- uart_tx.sv
#         +-- .ipynb_checkpoints
#             |-- uart_rx-checkpoint.sv
#             |-- uart_test.sv-checkpoint.bak
#             |-- uart_tx-checkpoint.sv
#         |-- uart_rx.sv
#         |-- uart_test.sv.bak
#     +-- incremental_db
#         |-- README
#         +-- compiled_partitions
#             |-- top.root_partition.map.dpi
#             |-- top.root_partition.map.hbdb.hb_info
#             |-- top.root_partition.map.cdb
#             |-- top.rrp.hdb
#             |-- top.root_partition.cmp.rcfdb
#             |-- top.root_partition.cmp.logdb
#             |-- top.root_partition.cmp.cdb
#             |-- top.root_partition.cmp.hdb
#             |-- top.root_partition.map.kpt
#             |-- top.root_partition.map.hbdb.sig
#             |-- top.root_partition.map.hbdb.hdb
#             |-- top.root_partition.cmp.ammdb
#             |-- top.root_partition.map.hbdb.cdb
#             |-- top.root_partition.map.hdb
#             |-- top.root_partition.cmp.dfp
#             |-- top.db_info
#     |-- tb.sv
#     +-- docs
#         |-- PIAX301-V2 SCH.pdf
# |-- file_tree.ipynb
