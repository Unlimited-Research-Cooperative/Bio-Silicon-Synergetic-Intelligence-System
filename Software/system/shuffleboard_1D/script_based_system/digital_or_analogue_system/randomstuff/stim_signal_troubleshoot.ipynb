# %%
import pyaudio

p = pyaudio.PyAudio()
for i in range(pyaudio.PyAudio().get_device_count()):
    info = p.get_device_info_by_index(i)
    print(f"Device {i}: {info['name']}")
p.terminate()

# %%
import pyaudio
import numpy as np

p = pyaudio.PyAudio()
pyaudio_devices = [18, 19, 20, 21]  # Replace with actual indices if needed

def play_test_sound(device_index, duration=1, freq=1000, volume=0.5):
    RATE = 44100  # Default sample rate
    DURATION = duration  # Duration in seconds
    FREQ = freq  # Frequency in Hz
    VOLUME = volume  # Volume (0.0 to 1.0)

    t = np.linspace(0, DURATION, int(RATE * DURATION), endpoint=False)
    audio_data = (VOLUME * np.sin(2 * np.pi * FREQ * t)).astype(np.float32)

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=1,
                        rate=RATE,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate {RATE}")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate {RATE}: {e}")

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=1,
                        rate=48000,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate 48000")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate 48000: {e}")

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=1,
                        rate=22050,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate 22050")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate 22050: {e}")

for device_index in pyaudio_devices:
    try:
        play_test_sound(device_index)
    except Exception as e:
        print(f"Could not play sound on device {device_index}: {e}")

p.terminate()

# %%
import pyaudio
import numpy as np

p = pyaudio.PyAudio()
pyaudio_devices = [17, 18, 19, 20, 21, 22]  # Device indices

def play_test_sound(device_index, duration=0.5, freq=1000, volume=0.5):
    RATE = 44100  # Default sample rate
    DURATION = duration  # Duration in seconds
    FREQ = freq  # Frequency in Hz
    VOLUME = volume  # Volume (0.0 to 1.0)

    t = np.linspace(0, DURATION, int(RATE * DURATION), endpoint=False)
    audio_data = (VOLUME * np.sin(2 * np.pi * FREQ * t)).astype(np.float32)

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=1,
                        rate=RATE,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate {RATE}")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate {RATE}: {e}")

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=1,
                        rate=48000,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate 48000")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate 48000: {e}")

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=1,
                        rate=22050,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate 22050")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate 22050: {e}")

for device_index in pyaudio_devices:
    try:
        play_test_sound(device_index)
    except Exception as e:
        print(f"Could not play sound on device {device_index}: {e}")

p.terminate()

# %%
import pyaudio
import numpy as np

p = pyaudio.PyAudio()
pyaudio_devices = [17, 18, 19, 20, 21, 22]  # Replace with actual indices if needed

def play_test_sound(device_index, duration=2, freq=1000, volume=0.5):
    RATE = 44100  # Default sample rate
    DURATION = duration  # Duration in seconds
    FREQ = freq  # Frequency in Hz
    VOLUME = volume  # Volume (0.0 to 1.0)

    t = np.linspace(0, DURATION, int(RATE * DURATION), endpoint=False)
    audio_data = (VOLUME * np.sin(2 * np.pi * FREQ * t)).astype(np.float32)
    audio_data = np.tile(audio_data, (2, 1)).T.flatten()  # Convert to stereo by duplicating the signal for both channels

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=2,
                        rate=RATE,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate {RATE}")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate {RATE}: {e}")

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=2,
                        rate=48000,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate 48000")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate 48000: {e}")

    try:
        stream = p.open(format=pyaudio.paFloat32,
                        channels=2,
                        rate=22050,
                        output=True,
                        output_device_index=device_index)
        stream.write(audio_data.tobytes())
        stream.stop_stream()
        stream.close()
        print(f"Played test sound on device {device_index} with rate 22050")
    except Exception as e:
        print(f"Could not play sound on device {device_index} with rate 22050: {e}")

for device_index in pyaudio_devices:
    try:
        play_test_sound(device_index)
    except Exception as e:
        print(f"Could not play sound on device {device_index}: {e}")

p.terminate()

# %%
import subprocess

# List of ALSA hardware device names corresponding to the symlinks
alsa_devices = ["hw:21,0", "hw:20,0", "hw:19,0", "hw:18,0", 
                "hw:17,0", "hw:7,0", "hw:16,0", "hw:15,0", 
                "hw:14,0", "hw:13,0", "hw:12,0", "hw:11,0", 
                "hw:9,0", "hw:8,0"]

# Function to check device capabilities using aplay for playback
def check_playback_device_capabilities(device):
    try:
        result = subprocess.run(['aplay', '-D', device, '--dump-hw-params'], 
                                stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        print(f"Checking playback device {device}")
        if result.stdout:
            for line in result.stdout.split('\n'):
                if 'FORMAT' in line or 'RATE' in line or 'CHANNELS' in line:
                    print(line)
        else:
            print(f"No output for device {device}. Possible error: {result.stderr}")
    except Exception as e:
        print(f"Error checking playback device {device}: {e}")

# Function to check device capabilities using arecord for capture
def check_capture_device_capabilities(device):
    try:
        result = subprocess.run(['arecord', '-D', device, '--dump-hw-params'], 
                                stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        print(f"Checking capture device {device}")
        if result.stdout:
            for line in result.stdout.split('\n'):
                if 'FORMAT' in line or 'RATE' in line or 'CHANNELS' in line:
                    print(line)
        else:
            print(f"No output for device {device}. Possible error: {result.stderr}")
    except Exception as e:
        print(f"Error checking capture device {device}: {e}")

# Check capabilities for each device
for device in alsa_devices:
    check_playback_device_capabilities(device)
    check_capture_device_capabilities(device)

# %%
import pyaudio

def list_audio_devices():
    p = pyaudio.PyAudio()
    for i in range(p.get_device_count()):
        device_info = p.get_device_info_by_index(i)
        print(f"Device {i}: {device_info['name']} - {device_info['maxOutputChannels']} channels")
    p.terminate()

if __name__ == "__main__":
    list_audio_devices()
# Out:
# Device 0: Loopback: PCM (hw:0,0) - 32 channels
# Device 1: Loopback: PCM (hw:0,1) - 32 channels
# Device 2: HDA NVidia: HDMI 0 (hw:1,3) - 8 channels
# Device 3: HDA NVidia: HDMI 1 (hw:1,7) - 8 channels
# Device 4: HDA NVidia: HDMI 2 (hw:1,8) - 8 channels
# Device 5: HDA NVidia: HDMI 3 (hw:1,9) - 8 channels
# Device 6: HDA Creative: CA0132 Analog (hw:2,0) - 6 channels
# Device 7: HDA Creative: CA0132 Digital (hw:2,1) - 2 channels
# Device 8: HDA Creative: CA0132 What U Hear (hw:2,2) - 0 channels
# Device 9: HDA NVidia: HDMI 0 (hw:3,3) - 2 channels
# Device 10: HDA NVidia: HDMI 1 (hw:3,7) - 8 channels
# Device 11: HDA NVidia: HDMI 2 (hw:3,8) - 8 channels
# Device 12: HDA NVidia: HDMI 3 (hw:3,9) - 8 channels
# Device 13: Jabra BIZ 2400 II CC: USB Audio (hw:5,0) - 0 channels
# Device 14: USB 2.0 Camera: Audio (hw:6,0) - 0 channels
# Device 15: USB Audio: - (hw:7,0) - 8 channels
# Device 16: USB Audio: #1 (hw:7,1) - 2 channels
# Device 17: USB Audio: #2 (hw:7,2) - 2 channels
# ...

# %%
import pyaudio

p = pyaudio.PyAudio()

for i in range(p.get_device_count()):
    info = p.get_device_info_by_index(i)
    print(f"Device {i}: {info['name']}")
    print(f"  Max input channels: {info['maxInputChannels']}")
    print(f"  Max output channels: {info['maxOutputChannels']}")
    print(f"  Default sample rate: {info['defaultSampleRate']}")

p.terminate()
# Out:
# Device 0: Loopback: PCM (hw:0,0)
#   Max input channels: 32
#   Max output channels: 32
#   Default sample rate: 44100.0
# Device 1: Loopback: PCM (hw:0,1)
#   Max input channels: 32
#   Max output channels: 32
#   Default sample rate: 44100.0
# Device 2: HDA NVidia: HDMI 0 (hw:1,3)
#   Max input channels: 0
#   Max output channels: 8
#   Default sample rate: 44100.0
# Device 3: HDA NVidia: HDMI 1 (hw:1,7)
#   Max input channels: 0
#   Max output channels: 8
#   Default sample rate: 44100.0
# Device 4: HDA NVidia: HDMI 2 (hw:1,8)
#   Max input channels: 0
#   Max output channels: 8
#   Default sample rate: 44100.0
# Device 5: HDA NVidia: HDMI 3 (hw:1,9)
#   Max input channels: 0
#   Max output channels: 8
#   Default sample rate: 44100.0
# Device 6: HDA Creative: CA0132 Analog (hw:2,0)
#   Max input channels: 2
#   Max output channels: 6
#   Default sample rate: 44100.0
# Device 7: HDA Creative: CA0132 Digital (hw:2,1)
#   Max input channels: 0
#   Max output channels: 2
# ...
